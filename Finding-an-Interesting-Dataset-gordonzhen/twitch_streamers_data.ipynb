# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

csv_data = pandas.read_csv("twitchdata-update.csv")
csv_data.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
#Does becoming partner on twitch make you a top streamer? ANSWERED!
# - From the limited list of one thousand streamers Find out which are partnered (verified) on twitch
# -  Correspond with the streamers from #1-1000



total_partnered = csv_data [ csv_data ["Partnered"] == True]
total_partnered.sum()
# Out:
# Channel                 xQcOWsummit1gGaulesESL_CSGOTfueAsmongoldNICKME...
# Watch time(Minutes)                                          412305426195
# Stream time(minutes)                                            117775290
# Peak viewers                                                     36498205
# Average viewers                                                   4664724
# Followers                                                       562751329
# Followers gained                                                202365842
# Views gained                                                  11282522709
# Partnered                                                             978
# Mature                                                                225
# Language                EnglishEnglishPortugueseEnglishEnglishEnglishE...
# dtype: object

# %% [markdown]
# # Through the help with the sum() function I was able to find out from the amount of twitch streamers that are on this dataset which has been Partnered (verified). The results being of the one thousand total top streamers of 2020 , 978/1000 were indeed partnered therefore making the percentage 97.8. To conclude being partnered on twitch in regards to the great deficit of those that aren't statistically shows that most top streamers are Partnered.

# %%
#Does view count and viewer retention matter? In terms of being the top streamer 
# - Comparing peak viewers & average viewers (Does having high peak viewers & average viewers make you the top streamer)
average_viewers = csv_data ["Average viewers"].unique()
peak_viewers = csv_data ["Peak viewers"].unique()
streamers = csv_data ["Channel"].unique()

data = [average_viewers , peak_viewers]

name = [streamers]
colors = sns.color_palette('bright')[0:1000]

# plt.pie(data, labels = name , colors = colors , autopct='%')
# plt.show()
sns.FacetGrid( col = average_viewers[0:1000], row = streamers[0:1000] , data = data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 14
#      10 colors = sns.color_palette('bright')[0:1000]
#      12 # plt.pie(data, labels = name , colors = colors , autopct='%')
#      13 # plt.show()
# ---> 14 sns.FacetGrid( col = average_viewers[0:1000], row = streamers[0:1000] , data = data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:391, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     389     row_names = []
#     390 else:
# --> 391     row_names = categorical_order(data[row], row_order)
#     393 if col is None:
#     394     col_names = []
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# Correlation between stream time and average viewers (heatmap) ANSWERED!

# stream_time = csv_data [ csv_data ["Stream time(minutes)"]]
# stream_time

# avg_viewer = csv_data [csv_data["Average viewers"]]
# avg_viewer

# %%
sns.heatmap(csv_data.corr(), annot = True, cmap = 'viridis')
# Out:
# C:\Users\Gordon Zhen\AppData\Local\Temp\ipykernel_1356\1573612663.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(csv_data.corr(), annot = True, cmap = 'viridis')
# <AxesSubplot: >

# %% [markdown]
# # Correlation between stream time and average viewers.Through the raw data from the heatmap I've found that the total followers from the dataset to the followers gained is at a correlation of 0.72, which is the closes to being linear from the followers (x-axis) except for the 1:1 proportion  (followers to followers).
